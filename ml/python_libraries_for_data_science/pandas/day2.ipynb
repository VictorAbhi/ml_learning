# %% [markdown]
# # Working with employee Datasets

# %%
import pandas as pd

# %% [markdown]
# ## Loding the datasets

# %%
data = pd.read_csv('data_sets/employee.csv')

# %% [markdown]
# ### Viewing the dataframe

# %%
data.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# 1                  5                      0           0                  51
# 2                  4                      0           0                  47
# 3                  9                      0           0                  65
# 4                  7                      0           0                  61

# %%
data.sample(5)
# Out:
#        employee_id         department     region        education gender  \
# 2321         53086         Technology   region_2  Masters & above      m
# 3622         31849        Procurement  region_22        Bachelors      f
# 15126        45547        Procurement  region_22        Bachelors      m
# 14008        27296        Procurement   region_2              NaN      f
# 7465         47629  Sales & Marketing   region_2        Bachelors      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 2321                other                1   36                   1.0
# 3622             sourcing                1   29                   3.0
# 15126            sourcing                4   29                   3.0
# 14008               other                1   38                   4.0
# 7465             sourcing                1   54                   5.0
#
#        length_of_service  KPIs_met_more_than_80  awards_won  \
# 2321                   7                      0           0
# 3622                   2                      0           0
# 15126                  6                      0           0
# 14008                  9                      0           0
# 7465                   6                      1           0
#
#        avg_training_score
# 2321                   80
# 3622                   73
# 15126                  68
# 14008                  72
# 7465                   48

# %%
data.tail()
# Out:
#        employee_id  department    region  education gender  \
# 17412        64573  Technology  region_7  Bachelors      f
# 17413        49584          HR  region_7  Bachelors      m
# 17414        49584          HR  region_7  Bachelors      m
# 17415        49584          HR  region_7  Bachelors      m
# 17416        64573          HR  region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 17412            referred                2   30                   5.0
# 17413               other                1   33                   1.0
# 17414               other                1   33                   1.0
# 17415               other                1   33                   1.0
# 17416            referred                1   35                   5.0
#
#        length_of_service  KPIs_met_more_than_80  awards_won  \
# 17412                  6                      1           0
# 17413                  9                      0           0
# 17414                  9                      0           0
# 17415                  9                      0           0
# 17416                  4                      1           0
#
#        avg_training_score
# 17412                  81
# 17413                  51
# 17414                  51
# 17415                  51
# 17416                  81

# %%
data.shape
# Out:
# (17417, 13)

# %%
data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met_more_than_80', 'awards_won',
#        'avg_training_score'],
#       dtype='object')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17417 entries, 0 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            17417 non-null  int64
#  1   department             17417 non-null  object
#  2   region                 17417 non-null  object
#  3   education              16646 non-null  object
#  4   gender                 17417 non-null  object
#  5   recruitment_channel    17417 non-null  object
#  6   no_of_trainings        17417 non-null  int64
#  7   age                    17417 non-null  int64
#  8   previous_year_rating   16054 non-null  float64
#  9   length_of_service      17417 non-null  int64
#  10  KPIs_met_more_than_80  17417 non-null  int64
#  11  awards_won             17417 non-null  int64
#  12  avg_training_score     17417 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.7+ MB
# None

# %%
print(data.dtypes)
# Out:
# employee_id                int64
# department                object
# region                    object
# education                 object
# gender                    object
# recruitment_channel       object
# no_of_trainings            int64
# age                        int64
# previous_year_rating     float64
# length_of_service          int64
# KPIs_met_more_than_80      int64
# awards_won                 int64
# avg_training_score         int64
# dtype: object

# %%
print(data.nunique())
# Out:
# employee_id              17414
# department                   9
# region                      34
# education                    3
# gender                       2
# recruitment_channel          3
# no_of_trainings              9
# age                         41
# previous_year_rating         5
# length_of_service           34
# KPIs_met_more_than_80        2
# awards_won                   2
# avg_training_score          61
# dtype: int64

# %%
print(data.value_counts())
# Out:
# employee_id  department         region     education        gender  recruitment_channel  no_of_trainings  age  previous_year_rating  length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 49584        HR                 region_7   Bachelors        m       other                1                33   1.0                   9                  0                      0           51                    3
# 3            Procurement        region_22  Masters & above  f       other                1                38   5.0                   4                  1                      0           67                    1
# 52445        Sales & Marketing  region_1   Masters & above  m       other                1                37   5.0                   4                  1                      0           49                    1
# 52395        Operations         region_10  Masters & above  m       sourcing             1                37   5.0                   4                  1                      0           58                    1
# 52398        Sales & Marketing  region_19  Bachelors        m       sourcing             1                31   3.0                   3                  1                      0           50                    1
#                                                                                                                                                                                                                 ..
# 25734        Procurement        region_13  Bachelors        m       other                1                30   4.0                   5                  0                      0           71                    1
# 25736        Sales & Marketing  region_20  Bachelors        f       other                1                29   3.0                   2                  0                      0           44                    1
# 25738        Procurement        region_2   Masters & above  f       sourcing             3                36   3.0                   6                  1                      0           74                    1
# 25741        Procurement        region_16  Bachelors        f       sourcing             1                31   5.0                   7                  1                      0           73                    1
# 78295        Sales & Marketing  region_14  Bachelors        f       sourcing             1                36   3.0                   5                  0                      0           48                    1
# Name: count, Length: 15422, dtype: int64

# %%
data.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  17417.000000     17417.000000  17417.000000          16054.000000
# mean   39083.491129         1.250732     34.807774              3.345459
# std    22707.024087         0.595692      7.694046              1.265386
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19281.000000         1.000000     29.000000              3.000000
# 50%    39122.000000         1.000000     33.000000              3.000000
# 75%    58838.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met_more_than_80    awards_won  \
# count       17417.000000           17417.000000  17417.000000
# mean            5.801860               0.358845      0.023368
# std             4.175533               0.479675      0.151074
# min             1.000000               0.000000      0.000000
# 25%             3.000000               0.000000      0.000000
# 50%             5.000000               0.000000      0.000000
# 75%             7.000000               1.000000      0.000000
# max            34.000000               1.000000      1.000000
#
#        avg_training_score
# count        17417.000000
# mean            63.176322
# std             13.418179
# min             39.000000
# 25%             51.000000
# 50%             60.000000
# 75%             75.000000
# max             99.000000

# %%
data.describe(include='all')
# Out:
#          employee_id         department    region  education gender  \
# count   17417.000000              17417     17417      16646  17417
# unique           NaN                  9        34          3      2
# top              NaN  Sales & Marketing  region_2  Bachelors      m
# freq             NaN               5458      3918      11519  12314
# mean    39083.491129                NaN       NaN        NaN    NaN
# std     22707.024087                NaN       NaN        NaN    NaN
# min         3.000000                NaN       NaN        NaN    NaN
# 25%     19281.000000                NaN       NaN        NaN    NaN
# 50%     39122.000000                NaN       NaN        NaN    NaN
# 75%     58838.000000                NaN       NaN        NaN    NaN
# max     78295.000000                NaN       NaN        NaN    NaN
#
#        recruitment_channel  no_of_trainings           age  \
# count                17417     17417.000000  17417.000000
# unique                   3              NaN           NaN
# top                  other              NaN           NaN
# freq                  9751              NaN           NaN
# mean                   NaN         1.250732     34.807774
# std                    NaN         0.595692      7.694046
# min                    NaN         1.000000     20.000000
# 25%                    NaN         1.000000     29.000000
# 50%                    NaN         1.000000     33.000000
# 75%                    NaN         1.000000     39.000000
# max                    NaN         9.000000     60.000000
#
#         previous_year_rating  length_of_service  KPIs_met_more_than_80  \
# count           16054.000000       17417.000000           17417.000000
# unique                   NaN                NaN                    NaN
# top                      NaN                NaN                    NaN
# freq                     NaN                NaN                    NaN
# mean                3.345459           5.801860               0.358845
# std                 1.265386           4.175533               0.479675
# min                 1.000000           1.000000               0.000000
# 25%                 3.000000           3.000000               0.000000
# 50%                 3.000000           5.000000               0.000000
# 75%                 4.000000           7.000000               1.000000
# max                 5.000000          34.000000               1.000000
#
#           awards_won  avg_training_score
# count   17417.000000        17417.000000
# unique           NaN                 NaN
# top              NaN                 NaN
# freq             NaN                 NaN
# mean        0.023368           63.176322
# std         0.151074           13.418179
# min         0.000000           39.000000
# 25%         0.000000           51.000000
# 50%         0.000000           60.000000
# 75%         0.000000           75.000000
# max         1.000000           99.000000

# %%
print(data.memory_usage())
# Out:
# Index                       132
# employee_id              139336
# department               139336
# region                   139336
# education                139336
# gender                   139336
# recruitment_channel      139336
# no_of_trainings          139336
# age                      139336
# previous_year_rating     139336
# length_of_service        139336
# KPIs_met_more_than_80    139336
# awards_won               139336
# avg_training_score       139336
# dtype: int64

# %% [markdown]
# ## Check for the missing values

# %%
data.isnull().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
data['education'].head(60)
# Out:
# 0           Bachelors
# 1           Bachelors
# 2           Bachelors
# 3           Bachelors
# 4           Bachelors
# 5           Bachelors
# 6           Bachelors
# 7           Bachelors
# 8     Masters & above
# 9           Bachelors
# 10          Bachelors
# 11    Masters & above
# 12    Masters & above
# 13          Bachelors
# 14          Bachelors
# 15          Bachelors
# 16          Bachelors
# 17          Bachelors
# 18          Bachelors
# 19          Bachelors
# 20    Masters & above
# 21          Bachelors
# 22    Masters & above
# 23    Masters & above
# 24          Bachelors
# 25          Bachelors
# 26    Masters & above
# 27          Bachelors
# 28          Bachelors
# 29          Bachelors
# 30    Masters & above
# 31          Bachelors
# 32          Bachelors
# 33          Bachelors
# 34    Masters & above
# 35          Bachelors
# 36    Masters & above
# 37          Bachelors
# 38          Bachelors
# 39          Bachelors
# 40          Bachelors
# 41          Bachelors
# 42          Bachelors
# 43          Bachelors
# 44          Bachelors
# 45          Bachelors
# 46          Bachelors
# 47    Masters & above
# 48          Bachelors
# 49                NaN
# 50    Masters & above
# 51          Bachelors
# 52          Bachelors
# 53    Below Secondary
# 54          Bachelors
# 55    Masters & above
# 56          Bachelors
# 57    Masters & above
# 58          Bachelors
# 59          Bachelors
# Name: education, dtype: object

# %%
# check for missing values in each volumn
missing_data = data.isnull().sum()

# calculate the percentage of missing values
missing_percentage = (missing_data/len(data)) * 100

# combine missing data count and missing percentage
missing_info = pd.DataFrame({
    'Missing Values': missing_data,
    'Missing Percentage': missing_percentage
})

# Filter columns with missing data
missing_info = missing_info[missing_info['Missing Values']>0]

# Format the 'Missing Percentage' column to add a '%' symbol
missing_info['Missing Percentage'] = missing_info['Missing Percentage'].apply(lambda x: f"{x:.2f}%")

# Display the columns with missing data and their percentage
print(missing_info)
# Out:
#                       Missing Values Missing Percentage
# education                        771              4.43%
# previous_year_rating            1363              7.83%

# %%
education_unique_values = data['education'].unique()
previous_year_rating_unique_values = data['previous_year_rating'].unique()

print('Unique values in education:', education_unique_values)
print('Unique values in previous_year_rating_unique_values:', previous_year_rating_unique_values)
# Out:
# Unique values in education: ['Bachelors' 'Masters & above' nan 'Below Secondary']
# Unique values in previous_year_rating_unique_values: [nan  3.  1.  2.  4.  5.]

# %%
missing_columns = data.columns[data.isnull().any()]
missing_data_types = data[missing_columns].dtypes

print("\nData types of columns with missing values:")
print(missing_data_types)
# Out:
# Data types of columns with missing values:
# education                object
# previous_year_rating    float64
# dtype: object

# %%
data['education'].mode()[0]
# Out:
# 'Bachelors'

# %%
data['education'].value_counts()
# Out:
# education
# Bachelors          11519
# Masters & above     4841
# Below Secondary      286
# Name: count, dtype: int64

# %%
data['previous_year_rating'].mean()
# Out:
# 3.3454590756197833

# %%
# Identify numeric and categorical columns
numeric_columns = data.select_dtypes(include=['float64','int64']).columns
categorical_columns = data.select_dtypes(include=['object','category']).columns

# Fill missing values for numeric columns with the mean
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())

for col in categorical_columns:
    data[col] = data[col].fillna(data[col].mode()[0])
df=data.head()
df
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24              3.345459
# 1               other                1   31              3.000000
# 2               other                1   31              1.000000
# 3               other                3   31              2.000000
# 4            sourcing                1   30              4.000000
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# 1                  5                      0           0                  51
# 2                  4                      0           0                  47
# 3                  9                      0           0                  65
# 4                  7                      0           0                  61

# %%
df['education'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
# convert columns to the specified data types
df['employee_id'] = df['employee_id'].astype('int64')
df['department'] = df['department'].astype('object')
df['region'] = df['region'].astype('object')
df['education'] = df['education'].astype('object')
df['gender'] = df['gender'].astype('object')
df['recruitment_channel'] = df['recruitment_channel'].astype('object')
df['no_of_trainings'] = df['no_of_trainings'].astype('int64')
df['age'] = df['age'].astype('int64')
df['previous_year_rating'] = df['previous_year_rating'].astype('float64')
df['length_of_service'] = df['length_of_service'].astype('int64')
df['KPIs_met_more_than_80'] = df['KPIs_met_more_than_80'].astype('int64')
df['awards_won'] = df['awards_won'].astype('int64')
df['avg_training_score'] = df['avg_training_score'].astype('int64')

print(df.dtypes)
# Out:
# employee_id                int64
# department                object
# region                    object
# education                 object
# gender                    object
# recruitment_channel       object
# no_of_trainings            int64
# age                        int64
# previous_year_rating     float64
# length_of_service          int64
# KPIs_met_more_than_80      int64
# awards_won                 int64
# avg_training_score         int64
# dtype: object
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['employee_id'] = df['employee_id'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['department'] = df['department'].astype('object')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['region'] = df['region'].astype('object')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['education'] = df['education'].astype('object')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].astype('object')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['recruitment_channel'] = df['recruitment_channel'].astype('object')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['no_of_trainings'] = df['no_of_trainings'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df['age'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['previous_year_rating'] = df['previous_year_rating'].astype('float64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['length_of_service'] = df['length_of_service'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['KPIs_met_more_than_80'] = df['KPIs_met_more_than_80'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['awards_won'] = df['awards_won'].astype('int64')
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1258418974.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['avg_training_score'] = df['avg_training_score'].astype('int64')

# %%
df.dtypes
# Out:
# employee_id                int64
# department                object
# region                    object
# education                 object
# gender                    object
# recruitment_channel       object
# no_of_trainings            int64
# age                        int64
# previous_year_rating     float64
# length_of_service          int64
# KPIs_met_more_than_80      int64
# awards_won                 int64
# avg_training_score         int64
# dtype: object

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

df = df.drop_duplicates()
print(df.head())
# Out:
# Number of duplicate rows: 0
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24              3.345459
# 1               other                1   31              3.000000
# 2               other                1   31              1.000000
# 3               other                3   31              2.000000
# 4            sourcing                1   30              4.000000
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# 1                  5                      0           0                  51
# 2                  4                      0           0                  47
# 3                  9                      0           0                  65
# 4                  7                      0           0                  61

# %%
def age_group(age):
    if age < 30:
        return 'Youth'
    elif 30 <= age < 50:
        return 'Middle-aged'
    else:
        return 'Senior'

df['age_group'] = df['age'].apply(age_group)

# %%
df[['age', 'age_group']].head()
# Out:
#    age    age_group
# 0   24        Youth
# 1   31  Middle-aged
# 2   31  Middle-aged
# 3   31  Middle-aged
# 4   30  Middle-aged

# %%
df['years_at_company'] = df['length_of_service']

def training_score_category(score):
    if score < 50:
        return 'low'
    elif 50 <= score < 75:
        return 'Medium'
    else:
        return 'High'
df['training_score_category'] = df['avg_training_score'].apply(training_score_category)
df[['training_score_category','avg_training_score']]
df.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24              3.345459
# 1               other                1   31              3.000000
# 2               other                1   31              1.000000
# 3               other                3   31              2.000000
# 4            sourcing                1   30              4.000000
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score  \
# 0                  1                      1           0                  77
# 1                  5                      0           0                  51
# 2                  4                      0           0                  47
# 3                  9                      0           0                  65
# 4                  7                      0           0                  61
#
#      age_group  years_at_company training_score_category
# 0        Youth                 1                    High
# 1  Middle-aged                 5                  Medium
# 2  Middle-aged                 4                     low
# 3  Middle-aged                 9                  Medium
# 4  Middle-aged                 7                  Medium

# %%
def performance_rating(rating):
    if rating >= 4.0:
        return "Excellent"
    elif 3.0 <= rating < 4.0:
        return "Good"
    else:
        return "Needs Improvement"

df['perfomance'] = df['previous_year_rating'].apply(performance_rating)
df['awards_received'] = df['awards_won'].apply(lambda x: True if x >0 else False)
df.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24              3.345459
# 1               other                1   31              3.000000
# 2               other                1   31              1.000000
# 3               other                3   31              2.000000
# 4            sourcing                1   30              4.000000
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score  \
# 0                  1                      1           0                  77
# 1                  5                      0           0                  51
# 2                  4                      0           0                  47
# 3                  9                      0           0                  65
# 4                  7                      0           0                  61
#
#      age_group  years_at_company training_score_category         perfomance  \
# 0        Youth                 1                    High               Good
# 1  Middle-aged                 5                  Medium               Good
# 2  Middle-aged                 4                     low  Needs Improvement
# 3  Middle-aged                 9                  Medium  Needs Improvement
# 4  Middle-aged                 7                  Medium          Excellent
#
#    awards_received
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
df['age_and_service'] = df['age'] + df['length_of_service']
df['training_efficiency'] = df['avg_training_score']/df['no_of_trainings']
df['service_to_training_ratio'] = df['length_of_service']/df['no_of_trainings']
df['age_service_interaction'] = df['age'] * df['length_of_service']
df['experience_in_years'] = df['length_of_service']/12
df['education_level'] = df['education'].apply(lambda x: 1 if x in ['Masters','PhD']  else 0)
region_performance = df.groupby('region')['previous_year_rating'].mean().reset_index()
df = df.merge(region_performance, on='region', suffixes=('','_region_avg'))
df['is_young_employee']  = df['age'].apply(lambda x: 1 if x < 30 else 0)

df['is_experienced_employee'] = df['length_of_service'].apply(lambda x: 1  if x > 5 else 0)
df['employee_tenure_in_months'] = df['length_of_service'] * 12
df['age_times_performance'] = df['age'] * df['previous_year_rating']

def service_category(years):
    if years < 2:
        return 'Short Term'
    elif 2 <= years <= 5:
        return 'Medium Term'
    else:
        return 'Long Term'

df['service_category'] = df['length_of_service'].apply(service_category)
df.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24              3.345459
# 1               other                1   31              3.000000
# 2               other                1   31              1.000000
# 3               other                3   31              2.000000
# 4            sourcing                1   30              4.000000
#
#    length_of_service  ...  service_to_training_ratio  age_service_interaction  \
# 0                  1  ...                        1.0                       24
# 1                  5  ...                        5.0                      155
# 2                  4  ...                        4.0                      124
# 3                  9  ...                        3.0                      279
# 4                  7  ...                        7.0                      210
#
#    experience_in_years education_level  previous_year_rating_region_avg  \
# 0             0.083333               0                         3.345459
# 1             0.416667               0                         3.000000
# 2             0.333333               0                         1.000000
# 3             0.750000               0                         2.000000
# 4             0.583333               0                         4.000000
#
#   is_young_employee is_experienced_employee  employee_tenure_in_months  \
# 0                 1                       0                         12
# 1                 0                       0                         60
# 2                 0                       0                         48
# 3                 0                       1                        108
# 4                 0                       1                         84
#
#    age_times_performance  service_category
# 0              80.291018        Short Term
# 1              93.000000       Medium Term
# 2              31.000000       Medium Term
# 3              62.000000         Long Term
# 4             120.000000         Long Term
#
# [5 rows x 30 columns]

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data = pd.read_csv('data_sets/used_cars.csv', sep=';')

# %%
data.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999

# %% [raw]
# import os
# directory='data_sets'
# filename='used_cars.csv'
# file_path=os.path.join(directory,filename)

# %%
data['milage'] = data['milage'].str.replace(' mi.', '', regex=False)
data['milage'] = data['milage'].str.replace(',', '', regex=False)
data['milage'] = pd.to_numeric(data['milage'])

# %%
data['milage'].dtype
# Out:
# dtype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   int64
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 376.0+ KB

# %%
data.head()
# Out:
#       brand                            model  model_year  milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51000
# 1   Hyundai                     Palisade SEL        2021   34742
# 2     Lexus                    RX 350 RX 350        2022   22372
# 3  INFINITI                 Q50 Hybrid Sport        2015   88900
# 4      Audi        Q3 45 S line Premium Plus        2021    9835
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999

# %%
import re
data['engine_capacity'] = data['engine'].str.extract(r'(\d+\.\d+L|\d+L)')
data.head()
# Out:
#       brand                            model  model_year  milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51000
# 1   Hyundai                     Palisade SEL        2021   34742
# 2     Lexus                    RX 350 RX 350        2022   22372
# 3  INFINITI                 Q50 Hybrid Sport        2015   88900
# 4      Audi        Q3 45 S line Premium Plus        2021    9835
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price engine_capacity
# 0  At least 1 accident or damage reported         Yes  $10,300            3.7L
# 1  At least 1 accident or damage reported         Yes  $38,005            3.8L
# 2                           None reported         NaN  $54,598             NaN
# 3                           None reported         Yes  $15,500            3.5L
# 4                           None reported         NaN  $34,999            2.0L

# %%
data['engine_capacity'].isnull().sum()
# Out:
# 377

# %%
data['price'] = data['price'].replace({'\$':'',',':''}, regex=True)
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\adabh\AppData\Local\Temp\ipykernel_10336\1741423943.py:1: SyntaxWarning: invalid escape sequence '\$'
#   data['price'] = data['price'].replace({'\$':'',',':''}, regex=True)
#       brand                            model  model_year  milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51000
# 1   Hyundai                     Palisade SEL        2021   34742
# 2     Lexus                    RX 350 RX 350        2022   22372
# 3  INFINITI                 Q50 Hybrid Sport        2015   88900
# 4      Audi        Q3 45 S line Premium Plus        2021    9835
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title  price engine_capacity
# 0  At least 1 accident or damage reported         Yes  10300            3.7L
# 1  At least 1 accident or damage reported         Yes  38005            3.8L
# 2                           None reported         NaN  54598             NaN
# 3                           None reported         Yes  15500            3.5L
# 4                           None reported         NaN  34999            2.0L

# %%
import numpy as np
import matplotlib.pyplot as plt
r = np.linspace(0,10,100)
theta = 2 * np.pi * r
plt.figure(figsize=(6,6))
plt.subplot(111,projection='polar')
plt.plot(theta,r)
plt.title('Polar Plot')
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)

plt.hexbin(x,y,gridsize=30, cmap='Blues')
plt.title('Hexbin Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar(label='count')
plt.show()

# %%
data = data.drop(columns=['horse_power'])
